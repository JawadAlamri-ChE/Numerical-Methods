# %% [markdown]
# ### This file has been acquired for the purpose of resolving mathematical quandaries through the utilization of functions encoded within the integration and root modules.

# %%
import integration as Int
import root as rt

# %% [markdown]
# #### Problem.1
# Calculate the numerical integration of the function $ f(x) = {x}^3 + 2{x}^2 $ over the interval $(-5,5)$ employing Riemann Sum's, Trapezoidal, and Simpson's Rule.

# %%
fx = lambda x: x**3 + 2*x**2
a,b = -5,5
n = 100
Int.Riemann_Sums(fx,a,b,n)
# Out:
# 166.6500000000001

# %%
Int.Trapezoidal(fx,a,b,n)
# Out:
# 166.7000000000001

# %%
Int.Simpsons_Rule(fx,a,b,n)
# Out:
# 4.74881705059921

# %% [markdown]
# #### Problem.2
# Calculate the roots of the function $f(x) = (3sin(x) +9) - ({x}^2 - cos(x))$ over the interval $(-5,5)$ using Bisection,     False position,Newton Raphson, and Secant methods.
# "The function code is already built in the root module"

# %%
# %run root.py
# Out:
# ╒════════════╤════════════════════╤════════════════════════════╤═══════════════════╤════════════════════╕
# │ Function   │     f(x)           │ (3sin(x)+9)−(x^2−cos(x))   │ Interval          │   (-5,5)           │
# ╞════════════╪════════════════════╪════════════════════════════╪═══════════════════╪════════════════════╡
# │ Method     │ Bisection          │ False_position             │ Newton_Raphson    │ Secant             │
# ├────────────┼────────────────────┼────────────────────────────┼───────────────────┼────────────────────┤
# │ Root       │ 2.9374871253967285 │ 2.9374872036226005         │ 2.937487205108386 │ 2.9374872070887035 │
# ╘════════════╧════════════════════╧════════════════════════════╧═══════════════════╧════════════════════╛
